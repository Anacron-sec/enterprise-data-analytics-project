# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
original = pd.read_csv('../data/engineered/powerelectricity_test.csv')
predictions = pd.read_csv('../predictions/preds.csv')

# %%
predictions = predictions['prediction']

# %%
original['delta_y'].plot(figsize=(15,10))

# %%
original['delta_y'].plot(figsize=(15,10))
predictions.plot(figsize=(15,10), color='orange')
plt.show()

# %%
original['delta_y'][:2000].plot(figsize=(15,10))
predictions[:2000].plot(figsize=(15,10), color='orange')
plt.show()
