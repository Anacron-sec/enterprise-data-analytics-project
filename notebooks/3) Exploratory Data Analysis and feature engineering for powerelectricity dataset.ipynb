# %% [markdown]
# We now proceed to analyze the dataset to check for patterns and have a more general sense on how to make predictions and on what values.

# %% [markdown]
# First we import the necessary libraries we need to explore data

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from fastai.tabular import *

# %% [markdown]
# Let's import the data

# %%
pe_df = pd.read_csv('../data/processed/powerelectricity.csv')
pe_df.describe()
# Out:
#        electric_power    rms_current
# count   166070.000000  166070.000000
# mean        12.055046      63.157751
# std          2.597444      13.608303
# min          3.290496      17.239280
# 25%         10.051912      52.663103
# 50%         10.928413      57.255193
# 75%         14.078360      73.758121
# max         30.629625     160.472074

# %%
pe_df['srtDate'] = pd.to_datetime(pe_df['srtDate'], utc=True)

# %%
pe_df.head()
# Out:
#                            idsensor        sensortype  \
# 0  jzv://powerelectricity/0000#1012  powerelectricity
# 1  jzv://powerelectricity/0000#1012  powerelectricity
# 2  jzv://powerelectricity/0000#1012  powerelectricity
# 3  jzv://powerelectricity/0000#1012  powerelectricity
# 4  jzv://powerelectricity/0000#1012  powerelectricity
#
#                            srtDate  electric_power  rms_current
# 0 2018-03-22 15:17:24.296000+00:00       11.393908    59.693973
# 1 2018-03-22 15:17:24.296000+00:00       11.416760    59.813698
# 2 2018-03-22 15:17:24.296000+00:00       14.245332    74.632905
# 3 2018-03-22 15:18:56.724000+00:00       13.400139    70.204843
# 4 2018-03-22 15:20:29.049000+00:00       13.702492    71.788906

# %% [markdown]
# We can remove idsensor and sensortype (and later do this in our ML pipeline) to have a simpler dataframe

# %% [markdown]
# Ok now we have a proper multivariate time-series dataframe, let's take a look at the dates and

# %% [markdown]
# Let's check if there are duplicate values and explore the dates

# %%
unique_over_total = len(pe_df.srtDate.unique()) / len(pe_df.srtDate)
print(f'Unique values percentage = {round(unique_over_total, 3)}')
# Out:
# Unique values percentage = 0.292

# %% [markdown]
# We can see that almost 30% of the dates are unique so let's take a look at the most repetitive dates and check what is happening:

# %%
pe_df['srtDate'].value_counts()
# Out:
# 2018-05-29 22:28:51.523000+00:00    301
# 2018-05-11 22:29:11.729000+00:00     83
# 2018-05-31 22:28:33.446000+00:00     49
# 2018-04-10 15:20:08.655000+00:00     23
# 2018-04-06 19:24:07.272000+00:00     12
# 2018-04-12 09:49:09.041000+00:00     12
# 2018-03-22 16:59:18.503000+00:00     12
# 2018-04-26 07:11:43.348000+00:00     10
# 2018-04-23 14:30:44.507000+00:00     10
# 2018-05-04 14:43:37.966000+00:00      9
# 2018-05-18 04:17:33.986000+00:00      9
# 2018-05-15 20:57:26.905000+00:00      9
# 2018-04-27 19:18:28.011000+00:00      9
# 2018-05-26 12:06:45.794000+00:00      8
# 2018-05-25 17:58:22.161000+00:00      8
# 2018-04-30 20:58:10.530000+00:00      8
# 2018-03-24 11:01:01.634000+00:00      8
# 2018-05-10 07:37:14.106000+00:00      8
# 2018-05-15 17:23:33.506000+00:00      8
# 2018-05-07 22:45:42.515000+00:00      8
# 2018-03-30 02:22:45.856000+00:00      8
# 161527  jzv://powerelectricity/0000#1012  powerelectricity
# 161528  jzv://powerelectricity/0000#1012  powerelectricity
# 161529  jzv://powerelectricity/0000#1012  powerelectricity
# 161530  jzv://powerelectricity/0000#1012  powerelectricity
# 161531  jzv://powerelectricity/0000#1012  powerelectricity
# 161532  jzv://powerelectricity/0000#1012  powerelectricity
# 161533  jzv://powerelectricity/0000#1012  powerelectricity
# 161534  jzv://powerelectricity/0000#1012  powerelectricity
# 161535  jzv://powerelectricity/0000#1012  powerelectricity
# 161536  jzv://powerelectricity/0000#1012  powerelectricity
# 161537  jzv://powerelectricity/0000#1012  powerelectricity
# 161538  jzv://powerelectricity/0000#1012  powerelectricity
# 161539  jzv://powerelectricity/0000#1012  powerelectricity
# 161540  jzv://powerelectricity/0000#1012  powerelectricity
# 161541  jzv://powerelectricity/0000#1012  powerelectricity
# 161542  jzv://powerelectricity/0000#1012  powerelectricity
# ...                                  ...               ...
# 161784  jzv://powerelectricity/0000#1012  powerelectricity
# 161785  jzv://powerelectricity/0000#1012  powerelectricity
# 161786  jzv://powerelectricity/0000#1012  powerelectricity
# 161787  jzv://powerelectricity/0000#1012  powerelectricity
# 161788  jzv://powerelectricity/0000#1012  powerelectricity
# 161789  jzv://powerelectricity/0000#1012  powerelectricity
# 161790  jzv://powerelectricity/0000#1012  powerelectricity
# 161791  jzv://powerelectricity/0000#1012  powerelectricity
# 161792  jzv://powerelectricity/0000#1012  powerelectricity
# 161793  jzv://powerelectricity/0000#1012  powerelectricity
# 161794  jzv://powerelectricity/0000#1012  powerelectricity
# 161795  jzv://powerelectricity/0000#1012  powerelectricity
# 161796  jzv://powerelectricity/0000#1012  powerelectricity
# 161797  jzv://powerelectricity/0000#1012  powerelectricity
# 161798  jzv://powerelectricity/0000#1012  powerelectricity
# 161799  jzv://powerelectricity/0000#1012  powerelectricity
# 161800  jzv://powerelectricity/0000#1012  powerelectricity
# 161801  jzv://powerelectricity/0000#1012  powerelectricity
# 161802  jzv://powerelectricity/0000#1012  powerelectricity
# 161803  jzv://powerelectricity/0000#1012  powerelectricity
# 161804  jzv://powerelectricity/0000#1012  powerelectricity
# 161805  jzv://powerelectricity/0000#1012  powerelectricity
# 161806  jzv://powerelectricity/0000#1012  powerelectricity
# 161807  jzv://powerelectricity/0000#1012  powerelectricity
# 161808  jzv://powerelectricity/0000#1012  powerelectricity
# 161809  jzv://powerelectricity/0000#1012  powerelectricity
# 161810  jzv://powerelectricity/0000#1012  powerelectricity
# 161811  jzv://powerelectricity/0000#1012  powerelectricity
# 161812  jzv://powerelectricity/0000#1012  powerelectricity
# 161813  jzv://powerelectricity/0000#1012  powerelectricity
#
#                                 srtDate  electric_power  rms_current
# 161513 2018-05-29 22:28:51.523000+00:00       10.446408    54.729915
# 161514 2018-05-29 22:28:51.523000+00:00       10.469274    54.849711
# 161515 2018-05-29 22:28:51.523000+00:00       10.487345    54.944390
# 161516 2018-05-29 22:28:51.523000+00:00       10.487026    54.942713
# 
# 89477  jzv://powerelectricity/0000#1012  powerelectricity
# 89478  jzv://powerelectricity/0000#1012  powerelectricity
#
#                                srtDate  electric_power  rms_current
# 89469 2018-04-26 07:11:43.348000+00:00       13.907962    72.865389
# 89470 2018-04-26 07:11:43.348000+00:00       14.148290    74.124494
# 89471 2018-04-26 07:11:43.348000+00:00       14.142756    74.095497
# 89472 2018-04-26 07:11:43.348000+00:00       14.195601    74.372362
# 89473 2018-04-26 07:11:43.348000+00:00       14.191259    74.349613
# 89474 2018-04-26 07:11:43.348000+00:00       14.174489    74.261750
# 89475 2018-04-26 07:11:43.348000+00:00       14.193174    74.359644
# 89476 2018-04-26 07:11:43.348000+00:00       14.122766    73.990767
# 89477 2018-04-26 07:11:43.348000+00:00       14.141139    74.087026
# 89478 2018-04-26 07:11:43.348000+00:00       14.151502    74.141319

# %%
pe_df[pe_df['srtDate'] == '2018-04-12 09:49:09.041000+00:00']
# Out:
#                                idsensor        sensortype  \
# 56101  jzv://powerelectricity/0000#1012  powerelectricity
# 56102  jzv://powerelectricity/0000#1012  powerelectricity
# 56103  jzv://powerelectricity/0000#1012  powerelectricity
# 56104  jzv://powerelectricity/0000#1012  powerelectricity
# 56105  jzv://powerelectricity/0000#1012  powerelectricity
# 56106  jzv://powerelectricity/0000#1012  powerelectricity
# 56107  jzv://powerelectricity/0000#1012  powerelectricity
# 56108  jzv://powerelectricity/0000#1012  powerelectricity
# 56109  jzv://powerelectricity/0000#1012  powerelectricity
# 56110  jzv://powerelectricity/0000#1012  powerelectricity
# 56111  jzv://powerelectricity/0000#1012  powerelectricity
# 56112  jzv://powerelectricity/0000#1012  powerelectricity
#
#                                srtDate  electric_power  rms_current
# 56101 2018-04-12 09:49:09.041000+00:00       18.499982    96.923496
# 56102 2018-04-12 09:49:09.041000+00:00       18.239934    95.561079
# 56103 2018-04-12 09:49:09.041000+00:00       18.241128    95.567335
# 56104 2018-04-12 09:49:09.041000+00:00       18.615612    97.529298
# 56105 2018-04-12 09:49:09.041000+00:00       18.599279    97.443725
# 56106 2018-04-12 09:49:09.041000+00:00       18.307766    95.916458
# 56107 2018-04-12 09:49:09.041000+00:00       18.309652    95.926341
# 56108 2018-04-12 09:49:09.041000+00:00       18.355530    96.166699
# 56109 2018-04-12 09:49:09.041000+00:00       18.350043    96.137953
# 56110 2018-04-12 09:49:09.041000+00:00       18.396893    96.383404
# 56111 2018-04-12 09:49:09.041000+00:00       18.401150    96.405704
# 56112 2018-04-12 09:49:09.041000+00:00       18.297585    95.863121

# %% [markdown]
# They all have different values but don't seem to differ much, we can adopt a strategy of aggregation using the mean

# %%
aggr_pe_df = pe_df.groupby(['srtDate']).mean()
aggr_pe_df.describe()
# Out:
#        electric_power   rms_current
# count    48416.000000  48416.000000
# mean        12.096549     63.375190
# std          2.635419     13.807260
# min          3.290496     17.239280
# 25%         10.042822     52.615481
# 50%         10.964338     57.443405
# 75%         14.144733     74.105859
# max         30.595314    160.292313

# %% [markdown]
# Let's plot data for both electric_power and rms_current

# %%
aggr_pe_df.corr()
# Out:
#                 electric_power  rms_current
# electric_power             1.0          1.0
# rms_current                1.0          1.0

# %% [markdown]
# As we supposed they are both positively correlated by a factor of 1 (in fact to calculate power we can use current)

# %% [markdown]
# This means that when doing predictions we can just calculate one of them interchangeably

# %%
nans = lambda df: df[df.isnull().any(axis=1)]

# %% [markdown]
# We can make a function to print the missing data by different time frames to have an idea on how the sampling was intended or at least have an idea of what a good time frame for the data could be

# %%
def resample_stat(df, time_frames):
    for time_frame in time_frames:
        rdf = df.resample(time_frame).mean()
        print(f'For {time_frame} we have: \n\t dataset size: {len(rdf)}\n\t % missing values: {len(nans(rdf)) / len(rdf)} \n\t electric_power mean: {rdf.electric_power.mean()} \n\t electric_power std: {rdf.electric_power.std()}')

# %%
timeframes = ['s','10s','30s','Min','61s','62s','65s','70s','80s','90s','91s','2Min','122s','5Min','10Min','20Min','30Min','H', 'D']
resample_stat(aggr_pe_df, timeframes)
# Out:
# For s we have:
# 	 dataset size: 6073870
# 	 % missing values: 0.9920288053580337
# 	 electric_power mean: 12.09654915242641
# 	 electric_power std: 2.635419259015618
# For 10s we have:
# 	 dataset size: 607388
# 	 % missing values: 0.9202881848176124
# 	 electric_power mean: 12.09654915242641
# 	 electric_power std: 2.635419259015618
# For 30s we have:
# 	 dataset size: 202464
# 	 % missing values: 0.7609550339813498
# 	 electric_power mean: 12.096983964700877
# 	 electric_power std: 2.635553919504617
# For Min we have:
# 	 dataset size: 101232
# 	 % missing values: 0.5230065591907698
# 	 electric_power mean: 12.097198935570585
# 	 electric_power std: 2.635225315592977
# For 61s we have:
# 	 dataset size: 99572
# 	 % missing values: 0.5152452496685815
# 	 electric_power mean: 12.096953310047917
# 	 electric_power std: 2.6356109284252396
# For 62s we have:
# 	 dataset size: 97967
# 	 % missing values: 0.5073034797431788
# 	 electric_power mean: 12.097105363961308
# 	 electric_power std: 2.635678519832891
# For 65s we have:
# 	 dataset size: 93445
# 	 % missing values: 0.483535769704104
# 	 electric_power mean: 12.096854511930689
# 	 electric_power std: 2.635198450458035
# For 70s we have:
# 	 dataset size: 86770
# 	 % missing values: 0.44371326495332486
# 	 electric_power mean: 12.098173770721257
# 	 electric_power std: 2.635507717986092
# For 80s we have:
# 	 dataset size: 75924
# 	 % missing values: 0.36458827248300935
# 	 electric_power mean: 12.097568318071387
# 	 electric_power std: 2.6352441741142103
# For 90s we have:
# 	 dataset size: 67489
# 	 % missing values: 0.2860466150039266
# 	 electric_power mean: 12.097931989326423
# 	 electric_power std: 2.6353709715552194
# For 91s we have:
# 	 dataset size: 66747
# 	 % missing values: 0.2780799137039867
# 	 electric_power mean: 12.097069306252305
# 	 electric_power std: 2.635269705361568
# For 2Min we have:
# 	 dataset size: 50617
# 	 % missing values: 0.25957682201631865
# 	 electric_power mean: 12.09608276347527
# 	 electric_power std: 2.629996537813015
# For 122s we have:
# 	 dataset size: 49786
# 	 % missing values: 0.25939019001325675
# 	 electric_power mean: 12.099349021245672
# 	 electric_power std: 2.6331110610177793
# For 5Min we have:
# 	 dataset size: 20247
# 	 % missing values: 0.23672642860670717
# 	 electric_power mean: 12.100010002988682
# 	 electric_power std: 2.616642736392171
# For 10Min we have:
# 	 dataset size: 10124
# 	 % missing values: 0.2313314895298301
# 	 electric_power mean: 12.103499306232575
# 	 electric_power std: 2.6101175354030333
# For 20Min we have:
# 	 dataset size: 5063
# 	 % missing values: 0.2233853446573178
# 	 electric_power mean: 12.105959929269918
# 	 electric_power std: 2.6078201293757846
# For 30Min we have:
# 	 dataset size: 3375
# 	 % missing values: 0.21748148148148147
# 	 electric_power mean: 12.106921569319336
# 	 electric_power std: 2.5935499197351546
# For H we have:
# 	 dataset size: 1688
# 	 % missing values: 0.20201421800947866
# 	 electric_power mean: 12.108927309907417
# 	 electric_power std: 2.56675725800666
# For D we have:
# 	 dataset size: 71
# 	 % missing values: 0.056338028169014086
# 	 electric_power mean: 12.30590887291948
# 	 electric_power std: 1.7976797919607443

# %% [markdown]
# We can see there is 5% total day missing data, ~20% missing hourly data and so on.
# A good compromise looks like to be using a 2Min time frame. But we can be more analytic and try to find the sampling period using the mean and sum and to check when they are almost (or totally equal)

# %%
def mean_sum_check(df, resamplings):
    for resample in resamplings:
        mean_df = df.resample(resample).mean()
        sum_df = df.resample(resample).sum()
        mean_df.fillna(0.0000, inplace=True)
        count = 0
        for i in range(len(mean_df)):
            m = mean_df.electric_power[i]
            s = sum_df.electric_power[i]
            if m != s:
                count = count + 1
        print(f'For {resample}  % difference: {count / len(mean_df)}')

# %%
time_frames = ['15s','20s','30s','45s','60s','65s','90s','91s','92s','93s','95s','98s','100s','102s','2Min','5Min']

mean_sum_check(aggr_pe_df, time_frames)
# Out:
# For 15s  % difference: 0.0
# For 20s  % difference: 3.2927881354257902e-06
# For 30s  % difference: 8.890469416785207e-05
# For 45s  % difference: 0.00045934091986723564
# For 60s  % difference: 0.0012743006164058796
# For 65s  % difference: 0.0016587297340681685
# For 90s  % difference: 0.003422780008593993
# For 91s  % difference: 0.003445847753457084
# For 92s  % difference: 0.003998727677557141
# For 93s  % difference: 0.008819206271435572
# For 95s  % difference: 0.024336836836836837
# For 98s  % difference: 0.04691911776569483
# For 100s  % difference: 0.06246295686532763
# For 102s  % difference: 0.07788543888226503
# For 2Min  % difference: 0.2157575518106565
# For 5Min  % difference: 0.7533461747419371

# %% [markdown]
# Yes this confirms that data is probably meant to be taken every ~90s as the error start to increase exponentially after that.
# Let's create the 90s dataset and convert it to a supervised learning ready dataset

# %%
final_df = aggr_pe_df.resample('90s').mean()
final_df.plot(y=['electric_power'],figsize=(20,10))
# Out:
# /home/michele/miniconda3/envs/eda/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py:1172: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   "will drop timezone information.", UserWarning)

# %% [markdown]
# We will add both cyclic and normal date parts to the dataset

# %%
final_df['srtDate'] = final_df.index
#final_df_dt = add_datepart(final_df, field_name='srtDate',drop=False, time=True)
#final_df_dt = add_cyclic_datepart(final_df, field_name='srtDate', time=True)
final_df_dt = add_datepart(final_df, field_name='srtDate',time=True)

# %%
# Let's add a column to represent if the current column is an anomaly or not
#final_df_dt['anomaly'] = np.where(np.isnan(final_df_dt['electric_power']), True, False)

# %%
#final_df_dt.head(20)

# %% [markdown]
# Now let's backfill (with a limit of 3 consecutive values) the data and check how many values are still missing

# %%
before = len(nans(final_df_dt))

final_df_dt_filled = final_df_dt.fillna(method='bfill')

after = len(nans( final_df_dt_filled ))

print(f"Null values before and after {before} -> {after}")
# Out:
# Null values before and after 19305 -> 0

# %%
#final_df_dt_filled.plot(y=['electric_power'],figsize=(20,10))

# %%
NUM_LAGS = 5 # Increasing this makes your model more complex but also increases the opportunity to catch more seasonalities
LAG_START = 40*24*5 # The more lag gap the bigger the validation set can be as we use t-X as lag
LAG_END = LAG_START + NUM_LAGS # An equivalent number of rows will be discarded from the top of our train set as they will have NaN values

final_df_dt_filled['electric_power'] = np.log(final_df_dt_filled['electric_power'])

for i in range(LAG_START,LAG_END):
    lag_feature = 'electric_power_t-' + str(i)
    final_df_dt_filled[lag_feature] = final_df_dt_filled['electric_power'].shift(i)

final_df_dt_filled['electric_power_t-X'] = final_df_dt_filled['electric_power_t-'+str(LAG_START)]
final_df_dt_filled = final_df_dt_filled.drop('electric_power_t-'+str(LAG_START), axis=1)
    
final_df_dt_filled['delta_y'] = final_df_dt_filled['electric_power'] - final_df_dt_filled['electric_power_t-X']

# %%
final_df_dt_filled = final_df_dt_filled.tail(len(final_df_dt_filled) - LAG_END)
final_df_dt_filled.head()
# Out:
#                            electric_power  rms_current  srtYear  srtMonth  \
# srtDate
# 2018-03-27 15:24:00+00:00        2.642575    73.606023     2018         3
# 2018-03-27 15:25:30+00:00        2.631678    72.808291     2018         3
# 2018-03-27 15:27:00+00:00        2.676537    76.148759     2018         3
# 2018-03-27 15:28:30+00:00        2.754279    82.304955     2018         3
# 2018-03-27 15:30:00+00:00        2.722111    79.699492     2018         3
#
#                            srtWeek  srtDay  srtDayofweek  srtDayofyear  \
# srtDate
# 2018-03-27 15:24:00+00:00       13      27             1            86
# 2018-03-27 15:25:30+00:00       13      27             1            86
# 2018-03-27 15:27:00+00:00       13      27             1            86
# 2018-03-27 15:28:30+00:00       13      27             1            86
# 2018-03-27 15:30:00+00:00       13      27             1            86
#
#                            srtIs_month_end  srtIs_month_start  ...  srtHour  \
# srtDate                                                        ...
# 2018-03-27 15:24:00+00:00            False              False  ...       15
# 2018-03-27 15:25:30+00:00            False              False  ...       15
# 2018-03-27 15:27:00+00:00            False              False  ...       15
# 2018-03-27 15:28:30+00:00            False              False  ...       15
# 2018-03-27 15:30:00+00:00            False              False  ...       15
#
#                            srtMinute  srtSecond  srtElapsed  \
# srtDate
# 2018-03-27 15:24:00+00:00         24          0  1522164240
# 2018-03-27 15:25:30+00:00         25         30  1522164330
# 2018-03-27 15:27:00+00:00         27          0  1522164420
# 2018-03-27 15:28:30+00:00         28         30  1522164510
# 2018-03-27 15:30:00+00:00         30          0  1522164600
#
#                            electric_power_t-4801  electric_power_t-4802  \
# srtDate
# 2018-03-27 15:24:00+00:00               2.602248               2.607698
# 2018-03-27 15:25:30+00:00               2.463642               2.602248
# 2018-03-27 15:27:00+00:00               2.542991               2.463642
# 2018-03-27 15:28:30+00:00               2.703237               2.542991
# 2018-03-27 15:30:00+00:00               2.641289               2.703237
#
#                            electric_power_t-4803  electric_power_t-4804  \
# srtDate
# 2018-03-27 15:24:00+00:00               2.617423               2.595265
# 2018-03-27 15:25:30+00:00               2.607698               2.617423
# 2018-03-27 15:27:00+00:00               2.602248               2.607698
# 2018-03-27 15:28:30+00:00               2.463642               2.602248
# 2018-03-27 15:30:00+00:00               2.542991               2.463642
#
#                            electric_power_t-X   delta_y
# srtDate
# 2018-03-27 15:24:00+00:00            2.463642  0.178933
# 2018-03-27 15:25:30+00:00            2.542991  0.088687
# 2018-03-27 15:27:00+00:00            2.703237 -0.026700
# 2018-03-27 15:28:30+00:00            2.641289  0.112990
# 2018-03-27 15:30:00+00:00            2.566523  0.155588
#
# [5 rows x 24 columns]

# %% [markdown]
# The dataset is complete let's take a final brief look and save as a file

# %%
final_df_dt_filled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 62684 entries, 2018-03-27 15:24:00+00:00 to 2018-05-31 22:28:30+00:00
# Freq: 90S
# Data columns (total 24 columns):
# electric_power           62684 non-null float64
# rms_current              62684 non-null float64
# srtYear                  62684 non-null int64
# srtMonth                 62684 non-null int64
# srtWeek                  62684 non-null int64
# srtDay                   62684 non-null int64
# srtDayofweek             62684 non-null int64
# srtDayofyear             62684 non-null int64
# srtIs_month_end          62684 non-null bool
# srtIs_month_start        62684 non-null bool
# srtIs_quarter_end        62684 non-null bool
# srtIs_quarter_start      62684 non-null bool
# srtIs_year_end           62684 non-null bool
# srtIs_year_start         62684 non-null bool
# srtHour                  62684 non-null int64
# srtMinute                62684 non-null int64
# srtSecond                62684 non-null int64
# srtElapsed               62684 non-null int64
# electric_power_t-4801    62684 non-null float64
# electric_power_t-4802    62684 non-null float64
# electric_power_t-4803    62684 non-null float64
# electric_power_t-4804    62684 non-null float64
# electric_power_t-X       62684 non-null float64
# delta_y                  62684 non-null float64
# dtypes: bool(6), float64(8), int64(10)
# memory usage: 9.4 MB

# %%
import os

try:
    os.mkdir('../data/engineered/')
except:
    pass

# %%
#final_df_dt_filled.to_csv('../data/engineered/powerelectricity.csv', index=False)
#final_df_dt_filled

# %% [markdown]
# Let's make a train test split

# %%
train = final_df_dt_filled.iloc[0:-(LAG_START+1)]
test = final_df_dt_filled.iloc[-(LAG_START+1):-1]

# %% [markdown]
# And finally save to train and test files

# %%
train.to_csv('../data/engineered/powerelectricity_train.csv')
test.to_csv('../data/engineered/powerelectricity_test.csv')
