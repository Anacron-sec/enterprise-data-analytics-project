# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
predictions = pd.read_csv('../predictions/pred_reverted.csv')
predictions.set_index('srtDate', drop=True, inplace=True)
predictions.head()
# Out:
#                            electric_power     pred_y
# srtDate
# 2018-05-26 22:28:30+00:00       11.392506  11.459842
# 2018-05-26 22:30:00+00:00       11.239212  11.459842
# 2018-05-26 22:31:30+00:00       11.239212  11.459842
# 2018-05-26 22:33:00+00:00       11.239212  11.459842
# 2018-05-26 22:34:30+00:00       11.012593  11.459842

# %%
predictions['electric_power'].plot(figsize=(15,10), rot=45)
plt.show()

# %%
predictions['pred_y'].plot(figsize=(15,10), rot=45, color='orange')
plt.show()

# %%
predictions['electric_power'].plot(figsize=(15,10), rot=45)
predictions['pred_y'].plot(figsize=(15,10), rot=45, color='orange')
plt.show()
